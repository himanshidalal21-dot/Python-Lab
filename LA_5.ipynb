# %%
#LIST

# %%
nums = [10, 25, 5, 78, 30]
largest = max(nums)
print("Largest number:", largest)
# Out:
# Largest number: 78

# %%
nums = [10, 15, 20, 25, 30, 35]
result = [i for i in nums if i % 2 != 0]
print("After removing even numbers:", result)
# Out:
# After removing even numbers: [15, 25, 35]

# %%
nums = [1, 2, 3, 4, 5]
nums.reverse()
print("Reversed list:", nums)
# Out:
# Reversed list: [5, 4, 3, 2, 1]

# %%
nums = [2, 3, 4, 5]
squared = [i**2 for i in nums]
print("Squared list:", squared)
# Out:
# Squared list: [4, 9, 16, 25]

# %%
num = ["Hello", 34, 45, "", 40]
result = [i for i in num if i != ""]
print("Result:", result)
# Out:
# Result: ['Hello', 34, 45, 40]

# %%
nums = [10, 12, 15, 17, 20, 22]
result = [i for i in nums if i % 5 == 0]
print("Divisible by 5:", result)
# Out:
# Divisible by 5: [10, 15, 20]

# %%
num = [2, 3, 4, 5, 2, 6, 3, 2]
result = list(set(num))
print("Result:", result)
# Out:
# Result: [2, 3, 4, 5, 6]

# %%
result = []
for i in num:
    if i not in result:
        result.append(i)

print("Result:", result)
# Out:
# Result: [2, 3, 4, 5, 6]

# %%
list1 = [23, 24, 25, 26]
list2 = [27, 28, 29, 30]

list1.extend(list2)

print("Result:", list1)
# Out:
# Result: [23, 24, 25, 26, 27, 28, 29, 30]

# %%
nums = [2, 23, 24, 51, 46, 67]

even = [i for i in nums if i % 2 == 0]
odd = [i for i in nums if i % 2 != 0]

print("Even:", even)
print("Odd:", odd)
# Out:
# Even: [2, 24, 46]
# Odd: [23, 51, 67]

# %%
nums = [5, 2, 9, 1, 7]
nums.sort()
print("Sorted list:", nums)
# Out:
# Sorted list: [1, 2, 5, 7, 9]

# %%
nums = [10, 20, 30, 40, 50]
count = len(nums)
print("Total items:", count)
# Out:
# Total items: 5

# %%
chars = ['a', 'b', 'c', 'd', 'e']

reversed_list = []

for i in range(len(chars)-1, -1, -1):
    reversed_list.append(chars[i])

print("Reversed list:", reversed_list)
# Out:
# Reversed list: ['e', 'd', 'c', 'b', 'a']

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)

print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list1 = [5, 10, 15, 20, 25, 50, 20]

for i in range(len(list1)):
    if list1[i] == 20:
        list1[i] = 200
        break

print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %%
nums = [10, 5, 20, 8, 15]

range_value = max(nums) - min(nums)

print("Range:", range_value)
# Out:
# Range: 15

# %%
nums = [10, 20, 30, 40]

pos = int(input("Enter position: "))
value = int(input("Enter value: "))

nums.insert(pos, value)

print("Updated list:", nums)
# Out:
# Enter position: 20
# Enter value: 6
# Updated list: [10, 20, 30, 40, 6]

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

common = [i for i in list1 if i in list2]

print("Common elements:", common)
# Out:
# Common elements: [3, 4, 5]

# %%
nums = [10, 5, 8, 2, 15]

nums = list(set(nums))   # remove duplicates
nums.sort()

print("Second smallest:", nums[1])
# Out:
# Second smallest: 5

# %%
nums = [10, 20, 30, 40, 50, 60]

result = [nums[i] for i in range(len(nums)) if i % 2 != 0]

print("After removing even index elements:", result)
# Out:
# After removing even index elements: [20, 40, 60]

# %%
nums = [10, 20, 30, 40, 50, 60]

sum_odd = sum(nums[i] for i in range(len(nums)) if i % 2 != 0)

print("Sum of elements at odd indices:", sum_odd)
# Out:
# Sum of elements at odd indices: 120

# %%
#STRING

# %%
s = "Hello"
for ch in s:
    print(ch)
# Out:
# H
# e
# l
# l
# o

# %%
print(s[0], s[2])
# Out:
# H l

# %%
s = "Hello world python"
for w in s.split():
    print(w, len(w))
# Out:
# Hello 5
# world 5
# python 6

# %%
for w in s.split():
    if len(w) % 2 == 0:
        print(w)
# Out:
# python

# %%
vowels = "aeiouAEIOU"
count = sum(1 for ch in s if ch in vowels)
print(count)
# Out:
# 4

# %%
def show(x):
    print(x)
show("Hello")
# Out:
# Hello

# %%
print("Hi " * 3)
# Out:
# Hi Hi Hi

# %%
s = "Hello"
s += " World"
print(s)
# Out:
# Hello World

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
print("lo" in "Hello")
# Out:
# True

# %%
print("\x48\x65\x6c\x6c\x6f")
# Out:
# Hello

# %%
s = 'He said "Hello"'
print(s)
# Out:
# He said "Hello"

# %%
print(r"Hello\nWorld")
# Out:
# Hello\nWorld

# %%
s = "abc"
n = len(s)
print(n*(n+1)//2)
# Out:
# 6

# %%
s = "hello"
print(s[::-1])
print("".join(reversed(s)))
res = ""
for i in s: res = i + res
print(res)
print(list(s)[::-1])
print(''.join([s[i] for i in range(len(s)-1,-1,-1)]))
# Out:
# olleh
# olleh
# olleh
# ['o', 'l', 'l', 'e', 'h']
# olleh

# %%
stack = list(s)
rev = ""
while stack:
    rev += stack.pop()
print(rev)
# Out:
# olleh

# %%
print(list(s))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
print(s[1:4])
# Out:
# ell

# %%
print((s[:3]) * 2)
# Out:
# helhel

# %%
s = "abcd"
s = s[1] + s[0] + s[3] + s[2]
print(s)
# Out:
# badc

# %%
s = "hello"
i = 2
print(s[:i] + s[i+1:])
# Out:
# helo

# %%
print("Hello " + "User")
# Out:
# Hello User

# %%
s1 = "abc"
s2 = "bcd"
print(set(s1) & set(s2))
# Out:
# {'c', 'b'}

# %%
from collections import Counter
print(Counter("hello"))
# Out:
# Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})

# %%
import re
text = "Call me 9876543210"
print(re.findall(r'\d{10}', text))
# Out:
# ['9876543210']

# %%
text = "I like Java"
print(text.replace("Java", "Python"))
# Out:
# I like Python

# %%
for ch in "ABC":
    print(ch, ord(ch))
# Out:
# A 65
# B 66
# C 67

# %%
s = "abc123"
print(s[::-1])

# %%
s = "hello world python"
words = s.split()
camel = words[0] + ''.join(w.capitalize() for w in words[1:])
print(camel)
# Out:
# helloWorldPython

# %%
print("hello world".title())
# Out:
# Hello World

# %%
s = "madam"
print(s == s[::-1])
# Out:
# True

# %%
s = "Hello World"
upper = sum(1 for c in s if c.isupper())
lower = sum(1 for c in s if c.islower())
print(upper, lower)
# Out:
# 2 8

# %%
letters = sum(1 for c in s if c.isalpha())
digits = sum(1 for c in s if c.isdigit())
print(letters, digits)
# Out:
# 10 0

# %%
lst = ['H','i']
print("".join(lst))
# Out:
# Hi

# %%
x = "Hello"
print(isinstance(x, str))
# Out:
# True

# %%
text = "hello world hello"
print(text.count("hello"))
# Out:
# 2

# %%
import re
print(bool(re.search("world", text)))
# Out:
# True

# %%
s = "hello"
print(s[:2] + s[3:])
# Out:
# helo

# %%
print(len(s))
count = 0
for _ in s: count += 1
print(count)
# Out:
# 5
# 5

# %%
s = "aeiouAEIOU"
print(all(v in s for v in "aeiou"))
# Out:
# True

# %%
from collections import Counter
s = "hello"
freq = Counter(s)
print(min(freq, key=freq.get))
# Out:
# h

# %%
s = "hello world"
print("-".join(s.split()))
# Out:
# hello-world

# %%
k = 4
print([w for w in s.split() if len(w) > k])
# Out:
# ['hello', 'world']

# %%
import re
print(bool(re.search(r'[^a-zA-Z0-9 ]', s)))
# Out:
# False

# %%
print(max(freq, key=freq.get))
# Out:
# l

# %%
s = "101010"
print(all(c in '01' for c in s))
# Out:
# True

# %%
s1 = "apple banana"
s2 = "banana mango"
set1 = set(s1.split())
set2 = set(s2.split())
print(list(set1 ^ set2))
# Out:
# ['apple', 'mango']

# %%
s = input("Enter string: ")

result = s.title()

print("Result:", result)
# Out:
# Enter string: ref trd gss
# Result: Ref Trd Gss

# %%
s = input("Enter string: ")

if s == s[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter string: madam
# Palindrome

# %%
text = input("Enter text: ")
word = input("Enter word to count: ")

count = text.count(word)

print("Occurrences:", count)
# Out:
# Enter text: hfGBEG GDSJhhw
# Enter word to count: 12
# Occurrences: 0

# %%
s = input("Enter string: ")
i = int(input("Enter index: "))

result = s[:i] + s[i+1:]

print("Result:", result)
# Out:
# Enter string: hello
# Enter index: 3
# Result: helo

# %%
s = input("Enter string: ")

words = s.split()
result = "-".join(words)

print("Result:", result)
# Out:
# Enter string: hello
# Result: hello

# %%
s = input("Enter string: ")

words = s.split()
camel = words[0] + ''.join(w.capitalize() for w in words[1:])

print("camelCase:", camel)
# Out:
# Enter string: hello india I am Himanshi
# camelCase: helloIndiaIAmHimanshi

# %%
s = input("Enter string: ")
print(s[::-1])
# Out:
# Enter string: Himanshi
# ihsnamiH

# %%
s = input("Enter string: ")
sub = input("Enter substring: ")

if sub in s:
    print("Present")
else:
    print("Not Present")
# Out:
# Enter string: hello
# Enter substring: he
# Present

# %%
s = input("Enter string: ")

upper = 0
lower = 0

for ch in s:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1

print("Uppercase:", upper)
print("Lowercase:", lower)
# Out:
# Enter string: Hello
# Uppercase: 1
# Lowercase: 4

# %%
s = input("Enter string: ")

letters = 0
digits = 0

for ch in s:
    if ch.isalpha():
        letters += 1
    elif ch.isdigit():
        digits += 1

print("Letters:", letters)
print("Digits:", digits)
# Out:
# Enter string: gd23hfgKHG
# Letters: 8
# Digits: 2

# %%
lst = ['H', 'e', 'l', 'l', 'o']

result = "".join(lst)

print("String:", result)
# Out:
# String: Hello

# %%
text = input("Enter paragraph: ")
old = input("Enter word to replace: ")
new = input("Enter new word: ")

result = text.replace(old, new)

print("Updated text:", result)
# Out:
# Enter paragraph: Apple is red
# Enter word to replace: Apple
# Enter new word: Ball
# Updated text: Ball is red

# %%
#TUPLE

# %%
t = (10, "hello", 3.14)
print(t)
# Out:
# (10, 'hello', 3.14)

# %%
t = (1, 2, 3, 4, 5)
print(t[2])
# Out:
# 3

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = (1, 2, 3)
a, b, c = t
print(a, b, c)
# Out:
# 1 2 3

# %%
t = (1, 3, 5, 7, 9)
print(7 in t)
# Out:
# True

# %%
t = (0, 1, 2, 3, 4, 5)
print(t[2:5])
# Out:
# (2, 3, 4)

# %%
t = (10, 20, 30, 40, 50)
print(len(t))
# Out:
# 5

# %%
t = (1, 2, 3)
print(t * 3)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
lst = [1, 2, 3]
print(tuple(lst))
# Out:
# (1, 2, 3)

# %%
t = (5, 12, 3, 8, 15)
print(min(t), max(t))
# Out:
# 3 15

# %%
t = (1, 2, 3, 2, 4, 2)
print(t.count(2))
# Out:
# 3

# %%
t = (True, True, False)
print(all(t))
# Out:
# False

# %%
t = (1, 2, 3, 4, 3, 5)
print(t.index(3))
# Out:
# 2

# %%
t = (5, 2, 8, 1, 3)
print(tuple(sorted(t)))
# Out:
# (1, 2, 3, 5, 8)

# %%
t = tuple(i**2 for i in range(1, 6))
print(t)
# Out:
# (1, 4, 9, 16, 25)

# %%
t = (1, 2, 3)
print(t)
# Out:
# (1, 2, 3)

# %%
t = (10, "hello", 3.14)
print(t)
# Out:
# (10, 'hello', 3.14)

# %%
t = (10, 20, 30)
print(t[1])
# Out:
# 20

# %%
t = (1, 2, 3)
a, b, c = t
print(a, b, c)
# Out:
# 1 2 3

# %%
t = (1, 2, 3)
lst = list(t)
lst.append(4)
t = tuple(lst)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = ('a', 'b', 'c')
print(''.join(t))
# Out:
# abc

# %%
t = (1, 2, 3, 4, 5, 6)
print(t[-4])
# Out:
# 3

# %%
t = (1, 2, 3)
t2 = t[:]
print(t2)
# Out:
# (1, 2, 3)

# %%
from collections import Counter
t = (1, 2, 2, 3, 3, 3)
print([i for i, c in Counter(t).items() if c > 1])
# Out:
# [2, 3]

# %%
t = (1, 2, 3)
print(2 in t)
# Out:
# True

# %%
lst = [1, 2, 3]
print(tuple(lst))
# Out:
# (1, 2, 3)

# %%
t = (1, 2, 3)
lst = list(t)
lst.remove(2)
t = tuple(lst)
print(t)
# Out:
# (1, 3)

# %%
t = (1, 2, 3, 4, 5)
print(t[1:4])
# Out:
# (2, 3, 4)

# %%
t = (1, 2, 3)
print(t.index(2))
# Out:
# 1

# %%
t = (1, 2, 3)
print(len(t))
# Out:
# 3

# %%
t = (1, 2, 3)
d = {i: i*i for i in t}
print(d)
# Out:
# {1: 1, 2: 4, 3: 9}

# %%
lst = [(1, 2), (3, 4), (5, 6)]
a, b = zip(*lst)
print(list(a), list(b))
# Out:
# [1, 3, 5] [2, 4, 6]

# %%
t = (1, 2, 3)
print(t[::-1])
# Out:
# (3, 2, 1)

# %%
lst = [(1, "a"), (2, "b")]
print(dict(lst))
# Out:
# {1: 'a', 2: 'b'}

# %%
lst = [(), (), ('',), ('a','b'), ('a','b','c'), ('d')]
result = [i for i in lst if i]
print(result)
# Out:
# [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %%
s = "python 3.0"
print(tuple(s))
# Out:
# ('p', 'y', 't', 'h', 'o', 'n', ' ', '3', '.', '0')

# %%
# Taking input from user
nums = tuple(map(int, input("Enter integers separated by space: ").split()))

# a) Total number of items
print("Total items:", len(nums))

# b) Last item
print("Last item:", nums[-1])

# c) Reverse order
print("Reversed tuple:", nums[::-1])

# d) Check if 5 exists
if 5 in nums:
    print("Yes")
else:
    print("No")

# e) Remove first & last, sort remaining
if len(nums) > 2:
    new_tuple = nums[1:-1]        # remove first & last
    sorted_tuple = tuple(sorted(new_tuple))
    print("After removing first & last and sorting:", sorted_tuple)
else:
    print("Not enough elements to perform operation")
# Out:
# Enter integers separated by space: 5
# Total items: 1
# Last item: 5
# Reversed tuple: (5,)
# Yes
# Not enough elements to perform operation

# %%
# Taking input
prices = tuple(map(int, input("Enter prices of items: ").split()))

# a) Total items sold
print("Total items sold:", len(prices))

# b) Cheapest item
print("Cheapest price:", min(prices))

# c) Costliest item
max_price = max(prices)
print("Costliest price:", max_price)

# d) Ascending order
print("Prices in ascending order:", tuple(sorted(prices)))

# e) Number of costliest items sold
count = prices.count(max_price)
print("Number of costliest items sold:", count)
# Out:
# Enter prices of items: 23 842 475 9 36
# Total items sold: 5
# Cheapest price: 9
# Costliest price: 842
# Prices in ascending order: (9, 23, 36, 475, 842)
# Number of costliest items sold: 1

# %%
# !git clone https://github.com/himanshidalal21-dot/Python-Lab.git
# Out:
# Cloning into 'Python-Lab'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 4), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 8.04 KiB | 8.04 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd Python-Lab
# Out:
# /content/Python-Lab/Python-Lab

# %%
# !git config --global user.name "himanshidalal21-dot"
# !git config --global user.email "himanshidalal21@gmail.com"
