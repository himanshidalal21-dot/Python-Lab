# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("/sample1.csv")

# a) Print complete report
print("\n--- Complete Book Report ---")
print(df)

# b) Books by given author
author = input("\nEnter author name: ")
print("\nBooks by", author)
print(df[df["Author"] == author])

# c) Books by given publisher
publisher = input("\nEnter publisher name: ")
print("\nBooks by publisher", publisher)
print(df[df["Publisher"] == publisher])

# d) Cheapest & costliest books
min_price = df["Price"].min()
max_price = df["Price"].max()

print("\nCheapest Book:")
print(df[df["Price"] == min_price][["Title", "Price"]])

print("\nCostliest Book:")
print(df[df["Price"] == max_price][["Title", "Price"]])

# e) Sort by year
print("\nBooks sorted by Year:")
print(df.sort_values(by="Year"))
# Out:
# --- Complete Book Report ---
#        Title Author  Edition  Year Publisher  Price
# 0     Python   John        1  2020       ABC    300
# 1         DS   Mary        2  2022       XYZ    500
# 2   AI Intro   John        3  2019       ABC    700
# 3  ML Guides    Sam        1  2021       PQR    450
#
# Enter author name: Mary
#
# Books by Mary
#   Title Author  Edition  Year Publisher  Price
# 1    DS   Mary        2  2022       XYZ    500
#
# Enter publisher name: ABC
#
# Books by publisher ABC
#       Title Author  Edition  Year Publisher  Price
# 0    Python   John        1  2020       ABC    300
# 2  AI Intro   John        3  2019       ABC    700
#
# Cheapest Book:
#     Title  Price
# 0  Python    300
#
# Costliest Book:
#       Title  Price
# 2  AI Intro    700
#
# Books sorted by Year:
#        Title Author  Edition  Year Publisher  Price
# 2   AI Intro   John        3  2019       ABC    700
# 0     Python   John        1  2020       ABC    300
# ...

# %%
import pandas as pd

# Create DataFrame
data = {
    "State": ["Maharashtra", "Gujarat", "Rajasthan", "Madhya Pradesh", "Karnataka"],
    "Area": [307713, 196244, 342239, 308245, 191791],   # in sq km
    "Population": [112374333, 60439692, 68548437, 72626809, 61095297]
}

df = pd.DataFrame(data)

# a) Complete information
print("\n--- State Information ---")
print(df)

# b) State with largest area
largest_area = df.loc[df["Area"].idxmax()]
print("\nState with largest Area:", largest_area["State"])

# c) State with largest population
largest_pop = df.loc[df["Population"].idxmax()]
print("State with largest Population:", largest_pop["State"])

# d) Population density = Population / Area
df["Density"] = df["Population"] / df["Area"]

print("\n--- With Population Density ---")
print(df)

# e) State with highest density
highest_density = df.loc[df["Density"].idxmax()]
print("\nState with highest Population Density:", highest_density["State"])
# Out:
# --- State Information ---
#             State    Area  Population
# 0     Maharashtra  307713   112374333
# 1         Gujarat  196244    60439692
# 2       Rajasthan  342239    68548437
# 3  Madhya Pradesh  308245    72626809
# 4       Karnataka  191791    61095297
#
# State with largest Area: Rajasthan
# State with largest Population: Maharashtra
#
# --- With Population Density ---
#             State    Area  Population     Density
# 0     Maharashtra  307713   112374333  365.192023
# 1         Gujarat  196244    60439692  307.982369
# 2       Rajasthan  342239    68548437  200.294055
# 3  Madhya Pradesh  308245    72626809  235.613908
# 4       Karnataka  191791    61095297  318.551428
#
# State with highest Population Density: Maharashtra

# %%
# !git clone https://github.com/himanshidalal21-dot/Python-Lab.git
# Out:
# Cloning into 'Python-Lab'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 30 (delta 14), reused 14 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 26.96 KiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd Python-Lab
# Out:
# /content/Python-Lab

# %%
# !git config --global user.name "himanshidalal21-dot"
# !git config --global user.email "himanshidalal21@gmail.com"
